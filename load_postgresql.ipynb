# %%
import pandas as pd

# %%
data = pd.read_csv('query_rating.csv')

# %%
data.head()
# Out:
#       tconst  average  votes
# 0  tt6632666      7.6   9998
# 1  tt0031210      7.5   9998
# 2  tt0118073      5.7   9997
# 3  tt2253608      9.0   9994
# 4  tt2678948      6.0   9992

# %%
data.head(15)
# Out:
#         tconst  average  votes
# 0    tt6632666      7.6   9998
# 1    tt0031210      7.5   9998
# 2    tt0118073      5.7   9997
# 3    tt2253608      9.0   9994
# 4    tt2678948      6.0   9992
# 5    tt1595996      9.8   9991
# 6    tt8312952      8.0    999
# 7   tt12687036      7.8    999
# 8    tt5979690      4.3    999
# 9    tt0739547      8.2    999
# 10   tt1381020      6.6    999
# 11   tt0079128      5.5    999
# 12   tt0253312      7.5    999
# 13   tt2040798      6.6    999
# 14   tt2196053      6.0    999
